# %% [markdown]
# # Pakistani Population Analysis

# %% [markdown]
# **Author Name**: Rizwan Rizwan\
# **Email:** rizwan.rewala@gmail.com

# %% [markdown]
# This dataset can be downloaded from the following link: [Kaggle](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset)
#
# **About Dataset**
#
# `Description`
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# `Features`
# Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# District: Districts within each division, representing larger administrative units.
#
# Sub-Division: Sub-divisions or tehsils within each district, providing more localized data.
#
# Area: The land area (in square kilometers) of each sub-division.
#
# Urban Population 2017: The population of urban areas within each sub-division for the year 2017.
#
# Rural Population 2017: The population of rural areas within each sub-division for the year 2017.
#
# Male Population 2017: The male population within each sub-division for the year 2017.
#
# Female Population 2017: The female population within each sub-division for the year 2017.
#
# Transgender Population 2017: The population of transgender individuals within each sub-division for the year 2017.
#
# Sex Ratio 2017: The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# Population in 1998: The total population of each sub-division as recorded in the 1998 census.
#
# Annual Growth Rate: The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# `Data Source`
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# `Data Usage`
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of this analysis:
# we will this at the end or during the process

# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset 
df=pd.read_csv('./data/population_of_pakistan.csv')

# %%
# explore the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   viePROVINCE                 528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
# composition of the data 
df.head()
# Out:
#   viePROVINCE             DIVISION               DISTRICT  \
# 0      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0  BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1     CHISHTIAN TEHSIL        1500.0             540342        273788
# 2    FORT ABBAS TEHSIL        2536.0             361240        182655
# 3    HAROONABAD TEHSIL        1295.0             382115        192278
# 4   MINCHINABAD TEHSIL        1818.0             452723        231506
#
#    FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# 0          302644                   42             104.70
# 1          266500                   54             102.73
# ...

# %%
# max column printing option 
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#   viePROVINCE             DIVISION               DISTRICT  \
# 0      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0  BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1     CHISHTIAN TEHSIL        1500.0             540342        273788
# 2    FORT ABBAS TEHSIL        2536.0             361240        182655
# 3    HAROONABAD TEHSIL        1295.0             382115        192278
# 4   MINCHINABAD TEHSIL        1818.0             452723        231506
#
#    FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# 0          302644                   42             104.70
# 1          266500                   54             102.73
# ...

# %%
# let see all column names at once 
df.columns
# Out:
# Index(['viePROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# let's have a look on dtypes 
df.dtypes
# Out:
# viePROVINCE                    object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
# summary statistics
df.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
# how many are the missing values
df.isnull().sum()
# Out:
# viePROVINCE                   0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# box plot 
sns.boxplot(df, y='AREA (sq.km)')
# Out:
# <AxesSubplot: ylabel='AREA (sq.km)'>

# %%
# histplot
sns.histplot(df, x='AREA (sq.km)')
# Out:
# <AxesSubplot: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['viePROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
sns.boxplot(df, y='ALL SEXES (RURAL)', x='DIVISION')
# Out:
# <AxesSubplot: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
# it is very hard to plot, therefore we will use groupby function to make tabulated data available
df['DIVISION'].nunique()
# Out:
# 28

# %%
df.groupby(['DIVISION']).size().sort_values(ascending=False)
# Out:
# DIVISION
# Quetta Division                 38
# Makran Division                 37
# MALAKAND DIVISION               33
# Karachi Division                30
# Hyderabad Division              30
# RAWALPINDI DIVISION             22
# Larkana Division                21
# GUJRANWALA DIVISION             20
# Naseerabad Division             19
# Zhob Division                   19
# Kalat Division                  18
# Mirpurkhas Division             18
# Sukkur Division                 18
# PESHAWAR DIVISION               18
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Shaheed Benazirabad Division    15
# DERA ISMAIL KHAN DIVISION       15
# BANNU DIVISION                  15
# HAZARA DIVISION                 15
# BAHAWALPUR DIVISION             15
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# SAHIWAL DIVISION                 7
# ...

# %%
df.groupby(['DISTRICT']).size().sort_values(ascending=False)
# Out:
# DISTRICT
# NORTH WAZIRISTAN DISTRICT       9
# KHUZDAR DISTRICT                9
# LASBELA DISTRICT                8
# SOUTH WAZIRISTAN DISTRICT       8
# DERA BUGTI DISTRICT             8
# KHAIRPUR DISTRICT               8
# KECH DISTRICT                   8
# SWAT DISTRICT                   7
# THARPARKAR DISTRICT             7
# KAMBAR SHAHDAD KOT DISTRICT     7
# KARACHI WEST DISTRICT           7
# MOHMAND DISTRICT                7
# RAWALPINDI DISTRICT             7
# MIRPUR KHAS DISTRICT            7
# BAJAUR DISTRICT                 7
# SARGODHA DISTRICT               6
# UPPER DIR DISTRICT              6
# FAISALABAD DISTRICT             6
# BAHAWALPUR DISTRICT             6
# KILLA SAIFULLAH DISTRICT        6
# KACHHI DISTRICT                 6
# ATTOCK DISTRICT                 6
# SANGHAR DISTRICT                6
# MALIR DISTRICT                  5
# KARACHI SOUTH DISTRICT          5
# KARACHI CENTRAL DISTRICT        5
# KALAT DISTRICT                  5
# ...

# %%
df.groupby('SUB DIVISION')['ALL SEXES (RURAL)'].mean()
# Out:
# SUB DIVISION
# 18-HAZARI TEHSIL                268160.0
# ABBOTTABAD TEHSIL               737167.0
# ADENZAI TEHSIL                  317526.0
# AHMADPUR EAST TEHSIL            902476.0
# AHMADPUR SIAL TEHSIL            365900.0
# AIRPORT TEHSIL                       0.0
# ALIPUR TEHSIL                   595880.0
# ALLAI TEHSIL                    180502.0
# ALPURI TEHSIL                   508361.0
# AMBAR UTMAN KHEL TEHSIL          61951.0
# ARAM BAGH TEHSIL                     0.0
# ARANJI SUB-TEHSIL                42318.0
# ARIF WALA TEHSIL                742723.0
# ASHWAT SUB-TEHSIL                20768.0
# ATTOCK TEHSIL                   222710.0
# AWARAN TEHSIL                     8584.0
# BABA KOT TEHSIL                  49480.0
# BABUZAI TEHSIL                  267947.0
# BADIN TALUKA                    322957.0
# BADINI SUB-TEHSIL                15345.0
# BAHAWALNAGAR TEHSIL             619550.0
# BAHAWALPUR CITY TEHSIL               0.0
# ...

# %%
df.columns
# Out:
# Index(['viePROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# print maximum values of the rows
pd.set_option('display.max_rows',None)

# %%
df.groupby(['viePROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION'])['POPULATION 1998 (RURAL)'].mean()
# Out:
# viePROVINCE  DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   3979.0
#                                                                          JOHAN SUB-TEHSIL                 12299.0
#                                                                          KALAT TEHSIL                     63919.0
#                                                                          MANGOCHAR TEHSIL                 41590.0
#                                                                          SURAB TEHSIL                     82253.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                28561.0
#                                                                          KARAKH SUB-TEHSIL                21984.0
# ...

# %%
df['ALL SEXES (RURAL)'].sum() # the rural population of Pakistan in 2017 was 132189531
# Out:
# 130034790

# %%
print('The rural population of Pakistan in 2017 was:', df['ALL SEXES (RURAL)'].sum())
# Out:
# The rural population of Pakistan in 2017 was: 130034790

# %%
print('The rural population of Pakistan in 1998 was:', df['POPULATION 1998 (RURAL)'].sum())
# Out:
# The rural population of Pakistan in 1998 was: 88401981

# %%
# How much Rural Population has increased from 1998 to 2017?
pop_rural_1998 = df['POPULATION 1998 (RURAL)'].sum()
pop_rural_2017 = df['ALL SEXES (RURAL)'].sum()

pop_change_rural= pop_rural_2017 - pop_rural_1998
pop_change_rural
print('The rural population of Pakistan has increased by:', pop_change_rural)
# Out:
# The rural population of Pakistan has increased by: 41632809

# %%
# How much Rural Population has increased from 1998 to 2017?
pop_urban_1998 = df['POPULATION 1998 (URBAN)'].sum()
pop_urban_2017 = df['ALL SEXES (URBAN)'].sum()

pop_change_urban= pop_urban_2017 - pop_urban_1998
pop_change_urban
print('The urban population of Pakistan has increased by:', pop_change_urban)
# Out:
# The urban population of Pakistan has increased by: 32059612

# %% [markdown]
# ## Assignment_01: Calculate the percent change in population?

# %%
# calculate the percent change in pouplation from rural population and urban population
percent_change = (pop_change_rural - pop_change_urban) / pop_change_rural * 100
print('The percent change in rural to urban population from 1998 to 2007 is:', percent_change,'%')
# Out:
# The percent change in rural to urban population from 1998 to 2007 is: 22.99435764711432 %

# %% [markdown]
# It is seen that rural population has incresed 23% from 1998 to 2017.

# %% [markdown]
# ## Assignment02: How to combine 3 columns in one column? make a seperate data of everything based on sex (Male, Female and Transgender)?

# %%
import pandas as pd

# assuming the data is stored in a DataFrame called 'df'
df['COMBINED_COLUMN_RURAL_SEX'] = df.apply(lambda x: '{} {} {}'.format(x['MALE (RURAL)'], x['FEMALE (RURAL)'], x['TRANSGENDER (RURAL)']), axis=1)

print(df['COMBINED_COLUMN_RURAL_SEX'])
# Out:
# 0         316864 302644 42
# 1         273788 266500 54
# 2         182655 178541 44
# 3         192278 189808 29
# 4         231506 221178 39
# 5         461525 440889 62
# 6                    0 0 0
# 7         239541 228346 51
# 8         171117 169620 10
# 9          112952 108476 3
# 10        288761 275612 49
# 11        382228 366927 63
# 12       500742 481157 119
# 13       536887 508580 110
# 14        516640 483247 79
# 15        109429 103213 10
# 16        410429 417124 49
# 17        353638 351884 42
# 18        300077 280483 32
# 19         104011 100150 8
# 20        398960 384606 46
# 21        307377 288463 40
# 22        285241 270521 33
# 23        560409 532894 51
# 24       711866 673133 110
# 25           18280 15909 2
# 26        377811 361435 53
# 27        254955 239095 59
# 28        204450 186658 36
# 29        173525 166193 36
# 30        141800 135447 21
# 31        168126 161259 22
# 32        143009 141136 25
# 33           17534 16561 6
# ...

# %%
import pandas as pd

# assuming the data is stored in a DataFrame called 'df'
df['COMBINED_COLUMN_URBAN_SEX'] = df.apply(lambda x: '{} {} {}'.format(x['MALE (URBAN)'], x['FEMALE (URBAN)'], x['TRANSGENDER (URBAN)']), axis=1)

print(df['COMBINED_COLUMN_URBAN_SEX'])
# Out:
# 0           98391 95402 47
# 1           75546 73851 27
# 2           31360 30150 18
# 3           71345 71236 19
# 4           36694 35590 10
# 5           90003 86081 26
# 6         350186 331842 88
# 7           62009 45927 12
# 8           57743 57853 17
# 9            20981 20507 4
# 10           24884 23995 4
# 11        118442 114373 52
# 12          26238 25637 13
# 13        247388 237127 91
# 14        133215 128365 42
# 15                   0 0 0
# 16        201554 195775 33
# 17           25837 25820 9
# 18           50363 46828 2
# 19           24515 23853 3
# 20          98457 94988 31
# 21           22504 21994 6
# 22          81219 78150 13
# 23        129553 124566 28
# 24        124916 115424 38
# 25                   0 0 0
# 26          55953 54121 16
# 27        109228 103394 39
# 28             7487 7056 2
# 29           17264 16819 4
# 30        143956 134539 33
# 31          54935 54657 23
# 32           24664 24123 9
# 33     1651684 1558106 368
# ...

# %%
df.head()
# Out:
#   viePROVINCE             DIVISION               DISTRICT  \
# 0      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4      PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0  BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1     CHISHTIAN TEHSIL        1500.0             540342        273788
# 2    FORT ABBAS TEHSIL        2536.0             361240        182655
# 3    HAROONABAD TEHSIL        1295.0             382115        192278
# 4   MINCHINABAD TEHSIL        1818.0             452723        231506
#
#    FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  \
# 0          302644                   42             104.70
# 1          266500                   54             102.73
# ...
